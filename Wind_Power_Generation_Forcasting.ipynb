# %% [markdown]
# Wind Power Generation Forcasting

# %%
pip install pandas numpy scikit-learn matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 #importing all necessary libraries
import pandas as pd #data manipulation
import numpy as np #numerical python - linear algebra
import matplotlib.pyplot as plt #visualization lib
import seaborn as sns
from sklearn.model_selection import train_test_split #sklearn-ML
from sklearn.preprocessing import StandardScaler #scaling

# %%
#Load the csv (Dataset) files
location1 = pd.read_csv('Location1[1].csv')
location2 = pd.read_csv('Location2[1].csv')
location3 = pd.read_csv('Location3[1].csv')
location4 = pd.read_csv('Location4[1].csv')

# %%
#see the Location 1
location1.head() #show you top 5 rows
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            28.5                   85         24.5
# 1  2017-01-02 01:00:00            28.4                   86         24.7
# 2  2017-01-02 02:00:00            26.8                   91         24.5
# 3  2017-01-02 03:00:00            27.4                   88         24.3
# 4  2017-01-02 04:00:00            27.3                   88         24.1
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power
# 0            1.4  0.1635
# 1            4.4  0.1424
# ...

# %%
#see the Location 4
location4.head(20) #show you top 20 rows
# Out:
#                    Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0   2017-01-02 00:00:00            22.7                   82         18.0
# 1   2017-01-02 01:00:00            22.0                   82         17.4
# 2   2017-01-02 02:00:00            21.7                   82         17.1
# 3   2017-01-02 03:00:00            21.7                   85         17.8
# 4   2017-01-02 04:00:00            22.4                   88         19.5
# 5   2017-01-02 05:00:00            22.8                   90         20.4
# 6   2017-01-02 06:00:00            23.8                   91         21.4
# 7   2017-01-02 07:00:00            26.8                   91         24.5
# 8   2017-01-02 08:00:00            28.5                   90         26.0
# 9   2017-01-02 09:00:00            29.8                   91         27.4
# 10  2017-01-02 10:00:00            31.1                   90         28.5
# 11  2017-01-02 11:00:00            32.8                   89         29.9
# ...

# %%
# Add a new colounm to identify the location
location1['Location'] = 'Location1'
location2['Location'] = 'Location1'
location3['Location'] = 'Location3'
location4['Location'] = 'Location4'

#concatenate to dataframe
merged_data = pd.concat([location1,location2,location3,location4], ignore_index=True)
merged_data.head(5656449)
# Out:
#                        Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0       2017-01-02 00:00:00            28.5                   85         24.5
# 1       2017-01-02 01:00:00            28.4                   86         24.7
# 2       2017-01-02 02:00:00            26.8                   91         24.5
# 3       2017-01-02 03:00:00            27.4                   88         24.3
# 4       2017-01-02 04:00:00            27.3                   88         24.1
# ...                     ...             ...                  ...          ...
# 175195  2021-12-31 19:00:00            25.5                   94         24.0
# 175196  2021-12-31 20:00:00            25.3                   92         23.2
# 175197  2021-12-31 21:00:00            24.9                   90         22.5
# 175198  2021-12-31 22:00:00            24.9                   89         22.1
# 175199  2021-12-31 23:00:00            24.9                   88         21.8
#
# ...

# %%
# save the merged dataset to a new CSV file
merged_data.to_csv('merged_location.csv', index=False)

# %%
# To see the basic information about the dataset
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175200 entries, 0 to 175199
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Time                 175200 non-null  object
#  1   temperature_2m       175200 non-null  float64
#  2   relativehumidity_2m  175200 non-null  int64
#  3   dewpoint_2m          175200 non-null  float64
#  4   windspeed_10m        175200 non-null  float64
#  5   windspeed_100m       175200 non-null  float64
#  6   winddirection_10m    175200 non-null  int64
#  7   winddirection_100m   175200 non-null  int64
#  8   windgusts_10m        175200 non-null  float64
#  9   Power                175200 non-null  float64
#  10  Location             175200 non-null  object
# dtypes: float64(6), int64(3), object(2)
# memory usage: 14.7+ MB

# %%
# To check the statistics of Dataset
merged_data.describe()
# Out:
#        temperature_2m  relativehumidity_2m    dewpoint_2m  windspeed_10m  \
# count   175200.000000        175200.000000  175200.000000  175200.000000
# mean        46.655994            70.155291      36.516241       4.157639
# std         22.012738            17.326678      20.933153       2.012682
# min        -31.200000             9.000000     -36.200000       0.000000
# 25%         30.200000            57.000000      21.900000       2.630000
# 50%         46.900000            72.000000      36.200000       3.850000
# 75%         65.300000            84.000000      54.600000       5.380000
# max        101.700000           100.000000      78.700000      18.530000
#
#        windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# count   175200.000000      175200.000000       175200.000000  175200.000000
# mean         6.879334         201.589446          201.539070       8.038205
# std          3.043964          99.639040          100.683777       3.617488
# ...

# %%
# check the missing values
merged_data.isnull().sum()
# Out:
# Time                   0
# temperature_2m         0
# relativehumidity_2m    0
# dewpoint_2m            0
# windspeed_10m          0
# windspeed_100m         0
# winddirection_10m      0
# winddirection_100m     0
# windgusts_10m          0
# Power                  0
# Location               0
# dtype: int64

# %%
# To check the duplicate rows
merged_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Encoded the ncategorial variables
merged_data = pd.get_dummies(merged_data,columns=['Location'],drop_first=True)
merged_data.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            28.5                   85         24.5
# 1  2017-01-02 01:00:00            28.4                   86         24.7
# 2  2017-01-02 02:00:00            26.8                   91         24.5
# 3  2017-01-02 03:00:00            27.4                   88         24.3
# 4  2017-01-02 04:00:00            27.3                   88         24.1
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power  Location_Location3  Location_Location4
# ...

# %%
merged_data.columns
# Out:
# Index(['Time', 'temperature_2m', 'relativehumidity_2m', 'dewpoint_2m',
#        'windspeed_10m', 'windspeed_100m', 'winddirection_10m',
#        'winddirection_100m', 'windgusts_10m', 'Power', 'Location_Location3',
#        'Location_Location4'],
#       dtype='object')

# %%
#let's remove time column
merged_data.drop('Time',axis=1,inplace=True)

# %%
merged_data.head()
# Out:
#    temperature_2m  relativehumidity_2m  dewpoint_2m  windspeed_10m  \
# 0            28.5                   85         24.5           1.44
# 1            28.4                   86         24.7           2.06
# 2            26.8                   91         24.5           1.30
# 3            27.4                   88         24.3           1.30
# 4            27.3                   88         24.1           2.47
#
#    windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# 0            1.26                146                 162            1.4
# 1            3.99                151                 158            4.4
# 2            2.78                148                 150            3.2
# 3            2.69                 58                 105            1.6
# 4            4.43                 58                  84            4.0
#
#     Power  Location_Location3  Location_Location4
# 0  0.1635               False               False
# ...
